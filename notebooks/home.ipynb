# %%
import json

# %%
with open('lists.ipynb') as f:
    data = json.load(f)

# %%
data
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'slideshow': {'slide_type': 'slide'}},
#    'source': ['## Python Lists, Tuples & Dictionaries\n',
#     '#### PCEP Exam block #4: Data Collections']},
#   {'cell_type': 'markdown',
#    'metadata': {'slideshow': {'slide_type': 'slide'}},
#    'source': ['## Lists\n',
#     '\n',
#     "#### What's the intended purpose of a Python `list`?\n",
#     '- To store an **ordered collection** of **related items**\n',
#     '- To allow items to be **retrieved** according to their **position**\n',
#     '- To enable items to be **added**, **removed** or **modified** \n',
#     '\n',
#     '#### What might we store in a list?\n',
#     '\n',
#     '- Names of players in a cricket team\n',
#     '- Songs in an album of music']},
#   {'cell_type': 'markdown',
#    'metadata': {'slideshow': {'slide_type': 'slide'}},
#    'source': ['### Lists: Examples & Syntax\n',
#     '\n',
#     '```python\n',
# ...

# %%
data['cells']
# Out:
# [{'cell_type': 'markdown',
#   'metadata': {'slideshow': {'slide_type': 'slide'}},
#   'source': ['## Python Lists, Tuples & Dictionaries\n',
#    '#### PCEP Exam block #4: Data Collections']},
#  {'cell_type': 'markdown',
#   'metadata': {'slideshow': {'slide_type': 'slide'}},
#   'source': ['## Lists\n',
#    '\n',
#    "#### What's the intended purpose of a Python `list`?\n",
#    '- To store an **ordered collection** of **related items**\n',
#    '- To allow items to be **retrieved** according to their **position**\n',
#    '- To enable items to be **added**, **removed** or **modified** \n',
#    '\n',
#    '#### What might we store in a list?\n',
#    '\n',
#    '- Names of players in a cricket team\n',
#    '- Songs in an album of music']},
#  {'cell_type': 'markdown',
#   'metadata': {'slideshow': {'slide_type': 'slide'}},
#   'source': ['### Lists: Examples & Syntax\n',
#    '\n',
#    '```python\n',
#    'scores = [16, 104, 3, 77, 29, 55, 18]\n',
# ...

# %%
cells = data['cells']

# %%
for cell in cells:
    cell['metadata'] = dict()

# %%
cells
# Out:
# [{'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['## Python Lists, Tuples & Dictionaries\n',
#    '#### PCEP Exam block #4: Data Collections']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['## Lists\n',
#    '\n',
#    "#### What's the intended purpose of a Python `list`?\n",
#    '- To store an **ordered collection** of **related items**\n',
#    '- To allow items to be **retrieved** according to their **position**\n',
#    '- To enable items to be **added**, **removed** or **modified** \n',
#    '\n',
#    '#### What might we store in a list?\n',
#    '\n',
#    '- Names of players in a cricket team\n',
#    '- Songs in an album of music']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['### Lists: Examples & Syntax\n',
#    '\n',
#    '```python\n',
#    'scores = [16, 104, 3, 77, 29, 55, 18]\n',
#    "members = ['John', 'Raj', 'Emily']\n",
#    "details = [4, 7, 'John', False]\n",
#    '```\n',
#    '\n',
# ...

# %%
data['cells'] = cells

# %%
with open('lists_new.ipynb', 'w') as f:
    f.write(json.dumps(data))
